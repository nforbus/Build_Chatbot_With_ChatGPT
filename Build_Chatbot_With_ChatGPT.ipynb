# %% [markdown]
# **Chat with an AI ChatBot with ChatGPT API on Google Colab**
#
# Original name for this course appears to have changed and now it sounds less impressive.  Originally it was "Build Chatbot with ChatGPT".  Hmm...
#
# **Course Objectives:**
# 1. Import Libraries and Define the OpenAI API Key
# 2. Chat iwth ChatGPT using the API Key
# 3. Define the Chatbot Conversation Function
# 4. Handle FAQ
# 5. Initiate Chatbot Conversation and Testing
# 6. Build a Customized Chatbot and Chat with it

# %% [markdown]
# In order to get started with this project they want me to log into Google Colab and upload their .ipynb/notebook file.  I instead added it to my own notebook.
#
# **Specified Course Objectives:**
# 1. Use Python to integrate the ChatGPT API for Chatbot functionality
# 2. Design a conversation flow to handle FAQ's in Customer Service scenarios.
# 3. Build and test the Customer Service Chatbot.

# %% [markdown]
# **Task 1: Import libraries and define the OpenAI Key for Access**
#
# pip install openai --upgrade does the same as pip install openai, which is that it installs the current version (1.16.2).  The course is advising if any trouble is happening to instead install the earlier version it was made with via the cli;  pip install openai==0.28
#
# Afterwards we need to get our OpenAI API key, which is located here;  https://platform.openai.com/api-keys
# This requires a signup and phone verification.  It told me since I used an existing email address that I would not get API credits...  So this may not even work lol.
#
# ![image.png](attachment:4135e56a-a393-4d92-b2ee-1cb27ba6ff99.png)

# %% [markdown]
# So I'm at the point in the lesson where I should be able to drop the key into Jupyter and it should recognize me, but instead its saying it doesnt know if openai is installed.
#
# ![image.png](attachment:a1f53935-b31e-4594-8829-f114c93d64dc.png)
#
# So some commands I've learned for this...
# 1. pip show openai (shows installed openai on desktop but not in jupyter)
# 2. pip list (lists all installed packages, is currently showing that no openai is installed)
# 3. Going into Jupyter -> Kernel -> restart kernel (might be needed for newly installed packages to be recognized)
#
# None of this worked.  What it was is that the Python scripts folder (located at directory: C:\Users\Samur\AppData\Local\Programs\Python\Python312\Scripts) was not added to PATH.  To fix this;
#
# 1. Open 'This PC'
# 2. Advanced System Settings
# 3. Environment Variables
# 4. Add the directory above to the list
# 5. Fixed

# %% [markdown]
# **Task 2: Chat with ChatGPT using the API key**
#
# The newer version of openai does not support the API interactions associated with the lesson, and trying to install the 0.28 openai version is not overwriting the existing, so I needed to uninstall openai.  However it was not working and the kernel was freezing.
#
# ```
# pip uninstall openai //resulted in freeze
# ```
#
# Apparently what I needed to do was
#
# ```
# pip uninstall openai --yes //there was a confirmation prompt not being seen
# ```
#
# Also had to add a different directory to PATH, I assume because I switched to using the Jupyter Labs version instead of the notebook...
#
# '''
# C:\Users\Samur\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311
# '''
#
# Now running into the issue where the davinci-002 model is 'deprecated' and no longer useable.  The lecture is out of date.  Going to have to find a different model.

# %% [markdown]
# **After a break...**  Getting back into this.  using AI model;  gpt-3.5-turbo-instruct
# Also had to 'fund' my usage of the service.  Spent $5, not sure how long it is supposed to last.  Changed the amount of tokens generated from 50 to 10 just in case.
#
# **Let's take a moment to talk about the OpenAI experience so far.**
# OpenAI is a website/service that grants API keys, API documentation, and access to a list of different AI models (chat, image creation, etc).  You log into it, generate an API key, fund your account, and then plug your API key in where needed.
#
# You can view a list of models here;  https://platform.openai.com/docs/models/continuous-model-upgrades
# In the case of this course, the model they had put into their notebook was out of date/deprecated, so I had to pick up a new one.
#
# You can check the status of your funding here;  https://platform.openai.com/usage
#
# You can check the API library here; https://platform.openai.com/docs/api-reference

# %% [markdown]
# **The API being used for this section;**
#
# ![image.png](attachment:8a7fd54a-b303-478f-bfee-f355c79d544a.png)
#
# ![image.png](attachment:a722c6bd-602a-4e38-9a82-d40234f05e67.png)

# %% [markdown]
# Import libraries;
# 1. openai
# 2. os (allows us to open files, modify processes)
#
# Set the API key to be used
#
# chat_with_gpt(message) is our function for sending a message.  It prompts a return from the model using our chat message as input.  I set it to only return 10 tokens (max of 10 words).
#
# Main method creates the conversation array where our conversation will be stored/appended.  Then we begin the back and forth in the while(true) which calls our chat function and prints the results until we say 'exit'.

# %% [markdown]
# **Task 3: Define the Chatbot Conversation Function**
# Develop a function to manage and streamline the conversation flow between the user and the chatbot (basically what we were using in the last task).  This one will be tailored for chat support interactions.
#
# Referencing the code here;  ![image.png](attachment:e58e4923-9459-41bb-9064-d83e59e32dba.png)
#
# There is a variable 'temperature' set to 0.7.  This number goes between 0 and 1, and the closer it is to 0, the more precise of a response we're looking for. The closer to 1, the more varied/creative the responses will be. A value of 0.7 is the 'default' temperature.

# %% [markdown]
# I have dialed back max tokens from 1024 to 50, because I'm cheap.
# No execution takes place in this task.

# %% [markdown]
# **Task 4:  Handle Frequently Asked Questions**
# Customize the chatbot to effectively respond to common FAQs related to e-commerce customer service.
#
# There are 3 code blocks in this section specifically to address different types of FAQ/queries.  Product information, Shipping & Returns, and Support.  These blocks serve as filters, capturing words from the users input just to see which category they are trying to go down.  No AI is used here, just input, word checking, and some print statements.
#
# What I've noticed so far though, looking into the next tasks, is that these 3 blocks are not referenced anywhere.  They do not seem to be accounted for in any code afterwards - no calls to their functions occur afterwards.  Not sure what the gameplan is here...

# %% [markdown]
# **Task 5: Initiate Chatbot Conversation and Testing**
# Start live conversations with the chatbot and conduct tests to evaluate its performance and response accuracy.
#
# Nothing new was introduced in this part of the lecture.  It is another conversation with the chatbot the same as in Task 2, with none of the other lessons rolled into it.  Kinda lame.  At least the author acknowledged there was no interaction with any customizations or domain yet...  There's hope.

# %% [markdown]
# **Task 6: Build a Customized Chatbot and Chat with it**
# Personalize the chatbot further (again, we have not personalized it at all yet...) to suit specific e-commerce scenarios and engage in advanced interactions.

# %% [markdown]
# Here's some meat and potatoes now.
#
# ![image.png](attachment:38244b37-d969-4e60-b4dc-e2202e59f249.png)
#
# ![image.png](attachment:444fb36f-9a45-4bba-88ef-3d782a3a6051.png)
#
# The prompt we are providing is for designating what we're looking for from the chatbot.  In this case we're asking it to tune itself to things regarding eBooks.  We're sending this prompt with each API call.
#
# ![image.png](attachment:90c57486-409d-4ab3-9564-c549b1161bce.png)
#
# Here is one of the ways the responses are filtered.  Specifically it looks for empty responses that might have bene generated, and omits them.
#
# ![image.png](attachment:2ae065a6-5f72-478b-93b5-19a1b035ab6f.png)
#
# Lastly, in order to make sure the chatbot is being used appropriately, the user is required to keep their prompt on topic by keeping their word choice within expected bounds.

# %% [markdown]
# ![image.png](attachment:ed0662a1-5afd-4cbb-b535-b326f95b9b20.png)
#
# Seems like its easily manipulatable though.

# %% [markdown]
# Its easy to make it start having problems though.
#
# ![image.png](attachment:c0576740-463c-45a1-be74-6f94a5b51fc8.png)

# %% [markdown]
# Chatbot: Chatbot: Chatbot: Chatbot:
#
# Classic.
